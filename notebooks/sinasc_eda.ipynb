# %% [markdown]
# <a href="https://colab.research.google.com/github/pathilink/triggo-ai_bootcamp_project/blob/main/notebooks/sinasc_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SINASC sample

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
# import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data

# %%
# display all columns
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/drive/MyDrive/test/triggo-ai/project/es_2021_raw.csv')
df.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  ESCMAE  \
# 0       1  2457121.0      210467        1        17          5     NaN
# 1       1  2551926.0      221100        1        35          2     5.0
# 2       1  2556847.0      291560        1        17          1     2.0
# 3       1  2556847.0      291560        1        18          5     4.0
# 4       1  2506122.0      292200        1        26          2     4.0
#
#    CODOCUPMAE  QTDFILVIVO  QTDFILMORT  CODMUNRES  GESTACAO  GRAVIDEZ  PARTO  \
# 0         NaN         1.0         1.0     320450       6.0         1      2
# 1    241335.0         0.0         0.0     320150       5.0         1      2
# 2    999992.0         0.0         0.0     320500       5.0         1      1
# 3    999992.0         1.0         0.0     320530       5.0         1      1
# 4    262105.0         1.0         0.0     320405       5.0         1      2
#
#    CONSULTAS    DTNASC  HORANASC  SEXO  APGAR1  APGAR5  RACACOR  PESO  \
# ...

# %%
df.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'STATE', 'YEAR'],
#       dtype='object')

# %%
print(*df.columns)
# Out:
# ORIGEM CODESTAB CODMUNNASC LOCNASC IDADEMAE ESTCIVMAE ESCMAE CODOCUPMAE QTDFILVIVO QTDFILMORT CODMUNRES GESTACAO GRAVIDEZ PARTO CONSULTAS DTNASC HORANASC SEXO APGAR1 APGAR5 RACACOR PESO IDANOMAL DTCADASTRO CODANOMAL NUMEROLOTE VERSAOSIST DTRECEBIM DIFDATA DTRECORIGA NATURALMAE CODMUNNATU CODUFNATU ESCMAE2010 SERIESCMAE DTNASCMAE RACACORMAE QTDGESTANT QTDPARTNOR QTDPARTCES IDADEPAI DTULTMENST SEMAGESTAC TPMETESTIM CONSPRENAT MESPRENAT TPAPRESENT STTRABPART STCESPARTO TPNASCASSI TPFUNCRESP TPDOCRESP DTDECLARAC ESCMAEAGR1 STDNEPIDEM STDNNOVA CODPAISRES TPROBSON PARIDADE KOTELCHUCK CONTADOR STATE YEAR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 63 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ORIGEM      500 non-null    int64
#  1   CODESTAB    499 non-null    float64
#  2   CODMUNNASC  500 non-null    int64
#  3   LOCNASC     500 non-null    int64
#  4   IDADEMAE    500 non-null    int64
#  5   ESTCIVMAE   500 non-null    int64
#  6   ESCMAE      498 non-null    float64
#  7   CODOCUPMAE  492 non-null    float64
#  8   QTDFILVIVO  497 non-null    float64
#  9   QTDFILMORT  498 non-null    float64
#  10  CODMUNRES   500 non-null    int64
#  11  GESTACAO    496 non-null    float64
#  12  GRAVIDEZ    500 non-null    int64
#  13  PARTO       500 non-null    int64
#  14  CONSULTAS   500 non-null    int64
#  15  DTNASC      500 non-null    int64
#  16  HORANASC    500 non-null    int64
#  17  SEXO        500 non-null    int64
#  18  APGAR1      495 non-null    float64
# ...

# %% [markdown]
# ## Prep

# %%
# missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#             Total  Percent
# DTRECORIGA    500    1.000
# CODANOMAL     499    0.998
# SERIESCMAE     99    0.198
# DTULTMENST     88    0.176
# IDADEPAI       63    0.126
# ...           ...      ...
# PARIDADE        0    0.000
# KOTELCHUCK      0    0.000
# CONTADOR        0    0.000
# STATE           0    0.000
# YEAR            0    0.000
#
# [63 rows x 2 columns]

# %%
# drop columns
['DTRECORIGA', 'CODANOMAL']
# Out:
# ['DTRECORIGA', 'CODANOMAL']

# %%
# date columns: int -> date
cols_dt = [col for col in df.columns if col.startswith('DT')]
cols_dt
# Out:
# ['DTNASC',
#  'DTCADASTRO',
#  'DTRECEBIM',
#  'DTRECORIGA',
#  'DTNASCMAE',
#  'DTULTMENST',
#  'DTDECLARAC']

# %%
df[['DTNASC',
 'DTCADASTRO',
 'DTRECEBIM',
#  'DTRECORIGA',
 'DTNASCMAE',
 'DTULTMENST',
 'DTDECLARAC']].head()
# Out:
#      DTNASC  DTCADASTRO   DTRECEBIM  DTNASCMAE  DTULTMENST  DTDECLARAC
# 0  29032021    14042021  14042021.0    9022004  23052020.0  31032021.0
# 1  26042021    11052021  11052021.0   10121985  24072020.0  26042021.0
# 2  30062021    14072021   3082021.0    3032004  30092020.0  30062021.0
# 3  30062021    14072021   3082021.0   31082002  30092020.0  30062021.0
# 4   2022021    11022021  27042021.0   23011995         NaN   2022021.0

# %%
df[['DTNASC',
 'DTCADASTRO',
 'DTRECEBIM',
#  'DTRECORIGA',
 'DTNASCMAE',
 'DTULTMENST',
 'DTDECLARAC']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DTNASC      500 non-null    int64
#  1   DTCADASTRO  500 non-null    int64
#  2   DTRECEBIM   498 non-null    float64
#  3   DTNASCMAE   500 non-null    int64
#  4   DTULTMENST  412 non-null    float64
#  5   DTDECLARAC  499 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 23.6 KB

# %%
# time columns: int -> time
cols_time = [col for col in df.columns if col.startswith('HORA')]
cols_time
# Out:
# ['HORANASC']

# %%
# list unique values per column
value_list = []
unique_list = []

for col in df:
  value_list.append(col)
  unique_list.append(df[col].unique())

# list(zip(col_list, unique_list))
df_unique = pd.DataFrame(
    {'column': value_list,
     'nunique': unique_list
     }
)

df_unique
# Out:
#         column                                            nunique
# 0       ORIGEM                                                [1]
# 1     CODESTAB  [2457121.0, 2551926.0, 2556847.0, 2506122.0, 2...
# 2   CODMUNNASC  [210467, 221100, 291560, 292200, 292550, 29313...
# 3      LOCNASC                                          [1, 3, 2]
# 4     IDADEMAE  [17, 35, 18, 26, 20, 24, 33, 25, 31, 30, 32, 2...
# ..         ...                                                ...
# 58    PARIDADE                                             [1, 0]
# 59  KOTELCHUCK                                    [2, 5, 9, 3, 4]
# 60    CONTADOR  [169420, 218699, 484077, 484078, 496820, 49682...
# 61       STATE                                               [ES]
# 62        YEAR                                             [2021]
#
# [63 rows x 2 columns]

# %%
# unique info per column
df_unique[df_unique['nunique'].apply(lambda x: len(x) <= 3)]
# Out:
#         column                      nunique
# 0       ORIGEM                          [1]
# 3      LOCNASC                    [1, 3, 2]
# 12    GRAVIDEZ                       [1, 2]
# 13       PARTO                       [2, 1]
# 17        SEXO                       [1, 2]
# 24   CODANOMAL  [nan, Q174Q189Q909        ]
# 29  DTRECORIGA                        [nan]
# 46  TPAPRESENT                       [1, 2]
# 47  STTRABPART                    [2, 1, 9]
# 49  TPNASCASSI                    [1, 2, 4]
# 50  TPFUNCRESP              [5.0, 2.0, nan]
# 54  STDNEPIDEM                          [0]
# 55    STDNNOVA                          [1]
# 56  CODPAISRES                          [1]
# 58    PARIDADE                       [1, 0]
# 61       STATE                         [ES]
# 62        YEAR                       [2021]

# %%
df_unique.query("column in ['ESTCIVMAE', 'ESCMAE', 'GESTACAO']")
# Out:
#        column                         nunique
# 5   ESTCIVMAE                 [5, 2, 1, 4, 9]
# 6      ESCMAE  [nan, 5.0, 2.0, 4.0, 3.0, 1.0]
# 11   GESTACAO       [6.0, 5.0, 4.0, 2.0, nan]

# %% [markdown]
# ## Test

# %%
# checks if all values are unique
if df['CONTADOR'].nunique() == len(df):
    print("All CONTADORs are unique.")
else:
    print("There are duplicate CONTADORs.")
# Out:
# All CONTADORs are unique.

# %%
df[['IDADEMAE', 'IDADEPAI', 'PESO', 'SEMAGESTAC', 'KOTELCHUCK']].describe()
# Out:
#         IDADEMAE    IDADEPAI         PESO  SEMAGESTAC  KOTELCHUCK
# count  500.00000  437.000000   500.000000  496.000000  500.000000
# mean    28.19800   32.432494  3280.898000   38.489919    4.592000
# std      6.61228    8.128450   493.012639    2.060670    1.143745
# min     13.00000   13.000000  1100.000000   23.000000    2.000000
# 25%     23.00000   27.000000  2998.750000   38.000000    5.000000
# 50%     28.00000   31.000000  3290.000000   39.000000    5.000000
# 75%     33.00000   37.000000  3570.000000   39.000000    5.000000
# max     43.00000   63.000000  5225.000000   45.000000    9.000000

# %%
# check outliers
f, axes = plt.subplots(2, 3, figsize=(8, 6))

sns.boxplot(x=df['IDADEMAE'], color='red', ax=axes[0, 0])
sns.boxplot(x=df['IDADEPAI'], color='orange', ax=axes[0, 1])
sns.boxplot(x=df['PESO'], color='blue', ax=axes[0, 2])
sns.boxplot(x=df['SEMAGESTAC'], color='green', ax=axes[1, 0])
sns.boxplot(x=df['KOTELCHUCK'], color='yellow', ax=axes[1, 1])

f.delaxes(ax=axes[1, 2])

plt.tight_layout()

# %%
df[['CONTADOR', 'STATE', 'YEAR']].head()
# Out:
#    CONTADOR STATE  YEAR
# 0    169420    ES  2021
# 1    218699    ES  2021
# 2    484077    ES  2021
# 3    484078    ES  2021
# 4    496820    ES  2021
